# %% [markdown]
# Using `Patchwork`, can you re-create this plot?

# %% [markdown]
# ![](img/patchwork_example.png)

# %%
# uncomment to load the libraries

library("tidyverse")
library("patchwork")
options(repr.plot.res = 300)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.8     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# 👇use these cells to 👀 the data.

# %%
iris |> head()
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
mpg |> head()
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
options(repr.plot.width = 8)
p=ggplot(mpg, aes(x=displ, y=hwy))+ geom_point()
p2=ggplot(iris, aes(x=Sepal.Length, y=Sepal.Width, color=Species))+geom_point()
p+p2
# Out:
# plot without title

# %% [markdown]
# # 🛑 Stop here. We'll continue after we discuss the code above. 🛑

# %%
# Load the `palmerpenguins` dataset.
library("palmerpenguins")

# %%
# What's in the penguins table?

penguins |> head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %% [markdown]
# Can you make this plot? 👇 What does this plot demonstrate?

# %%
p=ggplot(penguins, aes(x=body_mass_g, y=flipper_length_mm, color=species)) + geom_point(na.rm = TRUE)
p2=ggplot(penguins, aes(x=body_mass_g, y=flipper_length_mm, color=island)) + geom_point(na.rm = TRUE)+scale_color_brewer(type = "qual", palette = "Set2")
p+p2
# Out:
# plot without title

# %% [markdown]
# -how do I make the graph above look more zoomed in like below? I tried adjusting the height and length but couldn't make it similar. Thanks!

# %% [markdown]
# ![](img/patchwork_example_penguins.png)

# %% [markdown]
# 📍Hint: add `scale_color_brewer(type = "qual", palette = "Set2")` to adjust the colors of the second plot!
