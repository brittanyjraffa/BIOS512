# %% [markdown]
# Load the libraries below.

# %%
library("tidyverse")
library("jsonlite")
library("lubridate")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘jsonlite’
#
#
# The following object is masked from ‘package:purrr’:
#
#     flatten
#
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %% [markdown]
# This function `get_data` will get the new case counts over time from Utah.

# %%
get_data() |> head() # this retrieves data for Utah
# we want to get data for another state. get_data(NC) but we need to adjust the function to allow it to receive arguments
# Out:
#   date       new_cases state
# 1 2020-01-22 0         UT
# 2 2020-01-23 0         UT
# 3 2020-01-24 0         UT
# 4 2020-01-25 0         UT
# 5 2020-01-26 0         UT
# 6 2020-01-27 0         UT

# %%
get_data = function(state_code) {
        
    endpoint = paste0("https://data.cdc.gov/resource/9mfq-cb36.json?state=", state_code)
    
    # Can you make sense of what's happening here?👇
    df = fromJSON(url(endpoint)) |> 
        mutate(date = as_date(submission_date),
               new_cases = as.numeric(new_case)) |>
        select(date, new_cases, state) |>
        arrange(date)
    
    return(df)
    
    }

# %%
get_data('NC') |> head()
# Out:
#   date       new_cases state
# 1 2020-01-22 0         NC
# 2 2020-01-23 0         NC
# 3 2020-01-24 0         NC
# 4 2020-01-25 0         NC
# 5 2020-01-26 0         NC
# 6 2020-01-27 0         NC

# %% [markdown]
# Adjust the function above to take a state code as an argument and to set the `state` variable inside the function to the value of the argument.

# %% [markdown]
# Hint: here is an example of a function that just takes an argument called `state_code` and returns the value of the `state` variable.

# %% [markdown]
# ```R
# state_code_function = function(state_code) {
#
#     state = state_code
#
#     return(state)
#
# }
# ```

# %% [markdown]
# Use your function to plot new cases over time for any state.

# %%
cases = get_data('NY')

p = ggplot(cases, aes(x = date, y = new_cases)) + geom_col(width = 1)

p
# Out:
# plot without title

# %% [markdown]
# Here's a snippet to show how this workflow should work:
#
# ```r
# options(repr.plot.width=7, repr.plot.height=3, repr.plot.res=300)
#
# df = get_data("NC")
#
# p = ggplot(df, aes(x = date, y = new_cases)) + geom_col(width = 1)
#
# p
# ```

# %% [markdown]
# ## 🛑 STOP HERE 🛑

# %% [markdown]
# If you had data for multiple states in one table, what column would you use to "facet" your data by state?

# %% [markdown]
# Using the function you built above, capture the case data for two states in two separate tables.
#
# E.g. for each state do something like this:
#
# ```R
# df_UT = get_data("UT")
# ```

# %%
df_UT = get_data('UT')
df_OR = get_data('OR')

df_OR |> head()
# Out:
#   date       new_cases state
# 1 2020-01-22 0         OR
# 2 2020-01-23 0         OR
# 3 2020-01-24 0         OR
# 4 2020-01-25 0         OR
# 5 2020-01-26 0         OR
# 6 2020-01-27 0         OR

# %% [markdown]
# We can concatenate these two tables using the `rbind` function. Read the help documentation for `rbind` to see how it works, then concatenate your two tables.

# %%
rbind(df_UT, df_OR)
# Out:
#      date       new_cases state
# 1    2020-01-22 0         UT
# 2    2020-01-23 0         UT
# 3    2020-01-24 0         UT
# 4    2020-01-25 0         UT
# 5    2020-01-26 0         UT
# 6    2020-01-27 0         UT
# 7    2020-01-28 0         UT
# 8    2020-01-29 0         UT
# 9    2020-01-30 0         UT
# 10   2020-01-31 0         UT
# 11   2020-02-01 0         UT
# 12   2020-02-02 0         UT
# 13   2020-02-03 0         UT
# 14   2020-02-04 0         UT
# 15   2020-02-05 0         UT
# 16   2020-02-06 0         UT
# 17   2020-02-07 0         UT
# 18   2020-02-08 0         UT
# 19   2020-02-09 0         UT
# 20   2020-02-10 0         UT
# 21   2020-02-11 0         UT
# 22   2020-02-12 0         UT
# 23   2020-02-13 0         UT
# 24   2020-02-14 0         UT
# 25   2020-02-15 0         UT
# 26   2020-02-16 0         UT
# 27   2020-02-17 0         UT
# 28   2020-02-18 0         UT
# 29   2020-02-19 0         UT
# 30   2020-02-20 0         UT
# ⋮    ⋮          ⋮         ⋮
# 1971 2022-09-19    0      OR
# 1972 2022-09-20    0      OR
# 1973 2022-09-21 4544      OR
# 1974 2022-09-22    0      OR
# 1975 2022-09-23    0      OR
# 1976 2022-09-24    0      OR
# 1977 2022-09-25    0      OR
# 1978 2022-09-26    0      OR
# 1979 2022-09-27    0      OR
# 1980 2022-09-28 4269      OR
# 1981 2022-09-29    0      OR
# 1982 2022-09-30    0      OR
# 1983 2022-10-01    0      OR
# 1984 2022-10-02    0      OR
# 1985 2022-10-03    0      OR
# 1986 2022-10-04    0      OR
# 1987 2022-10-05 4237      OR
# 1988 2022-10-06    0      OR
# 1989 2022-10-07    0      OR
# 1990 2022-10-08    0      OR
# 1991 2022-10-09    0      OR
# 1992 2022-10-10    0      OR
# 1993 2022-10-11    0      OR
# 1994 2022-10-12 3306      OR
# 1995 2022-10-13    0      OR
# 1996 2022-10-14    0      OR
# 1997 2022-10-15    0      OR
# 1998 2022-10-16    0      OR
# 1999 2022-10-17    0      OR
# 2000 2022-10-18    0      OR

# %%
df_combined = rbind(df_UT, df_OR)

# %% [markdown]
# Use `geom_bar` to confirm that you indeed have two states in your concatenated table.

# %%
p=ggplot(df_combined, aes(x=state)) + geom_bar()
p
# Out:
# plot without title

# %%
df_UT |> nrow()
# Out:
# [1] 1000

# %%
df_combined |>
nrow()
# Out:
# [1] 2000

# %%
df_combined |> count(state)
# Out:
#   state n
# 1 OR    1000
# 2 UT    1000

# %%
df_combined |>
    group_by(state) |>
    summarize(n=n())
# Out:
#   state n
# 1 OR    1000
# 2 UT    1000

# %%
df_combined |> pull(state) # this will pull all of the values
# Out:
#    [1] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#   [15] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#   [29] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#   [43] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#   [57] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#   [71] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#   [85] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#   [99] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [113] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [127] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [141] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [155] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [169] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [183] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [197] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [211] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [225] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [239] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [253] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [267] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [281] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [295] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [309] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [323] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [337] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [351] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [365] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [379] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [393] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [407] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [421] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [435] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [449] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [463] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [477] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [491] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [505] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [519] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [533] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [547] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [561] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [575] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [589] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [603] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [617] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [631] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [645] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [659] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [673] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [687] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [701] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [715] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [729] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [743] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [757] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [771] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [785] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [799] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [813] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [827] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [841] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [855] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [869] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [883] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [897] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [911] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [925] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [939] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [953] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [967] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [981] "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT" "UT"
#  [995] "UT" "UT" "UT" "UT" "UT" "UT" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1009] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1023] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1037] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1051] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1065] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1079] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1093] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1107] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1121] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1135] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1149] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1163] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1177] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1191] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1205] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1219] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1233] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1247] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1261] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1275] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1289] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1303] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1317] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1331] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1345] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1359] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1373] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1387] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1401] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1415] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1429] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1443] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1457] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1471] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1485] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1499] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1513] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1527] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1541] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1555] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1569] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1583] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1597] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1611] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1625] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1639] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1653] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1667] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1681] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1695] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1709] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1723] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1737] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1751] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1765] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1779] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1793] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1807] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1821] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1835] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1849] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1863] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1877] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1891] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1905] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1919] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1933] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1947] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1961] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1975] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"
# [1989] "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR" "OR"

# %%
df_combined |> pull(state) |> unique() # this comfirms that this column "state" has both UT and OR
# Out:
# [1] "UT" "OR"

# %% [markdown]
# Make the new cases over time chart like we did above but this time `facet` by state.

# %%
p=ggplot(df_combined, aes(x=date, y=new_cases)) + geom_line() + facet_wrap(~state, ncol=1)
         
p

# for the most part, you can see the trends are similar across states with perhaps a bit more in OR.
# Out:
# plot without title
