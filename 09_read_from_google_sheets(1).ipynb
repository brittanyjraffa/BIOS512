# %% [markdown]
# 🧬 💵 Let's read salary data for biotech careers from [this public spreadsheet](https://docs.google.com/spreadsheets/d/1G0FmJhkOME_sv66hWmhnZS5qR2KMTY7nzkxksv46bfk).
#
# First, load the `googlesheets4` package.

# %%
library(googlesheets4)
gs4_deauth()

# %%
salary = read_sheet('https://docs.google.com/spreadsheets/d/1G0FmJhkOME_sv66hWmhnZS5qR2KMTY7nzkxksv46bfk/edit#gid=203339396')
salary |> head()
# Out:
# ✔ Reading from "salary survey test (Responses)".
#
# ✔ Range Form Responses 1.
#   Timestamp
# 1 2022-05-08 00:17:11
# 2 2022-05-08 00:38:17
# 3 2022-05-08 00:39:38
# 4 2022-05-08 00:40:46
# 5 2022-05-08 00:40:48
# 6 2022-05-08 00:42:01
#   Where are you located? (Country and/or nearest Major city or hubs names)
# 1 test
# 2 Los Angeles
# 3 San Diego
# 4 Illinois
# 5 New Jersey
# 6 Near boston
#   Biotech sub industry?                   [OPTIONAL] Company Name
# 1 Academia/Research                       poop
# 2 Consulting                              NA
# 3 Pharmaceutical (including “big pharma”) NA
# 4 Academia/Research                       NA
# 5 Pharmaceutical (including “big pharma”) Wuxi Biologics
# 6 Pharmaceutical (including “big pharma”) Abbvie
#   Company Details - public/private/start-up/ subsidiary of
# 1 Subsidiary
# 2 Private
# 3 Public
# 4 Academia/College/Universities
# 5 Public
# 6 Public
#   Approximate Company Size Role / Title of current position
# 1 NA                       pimp
# 2 50-200                   Senior Manager
# 3 50-200                   Research Associate I
# 4 5000+                    Researcher 1
# 5 1000-5000                Manufacturing technician III
# 6 5000+                    Senior scientist I
#   Highest achieved Formal Education Years of Experience
# 1 High School or Equivalent         1
# 2 Masters or Equivalent             6
# 3 Bachelors or Equivalent           0
# 4 Bachelors or Equivalent           2
# 5 Bachelors or Equivalent           6
# 6 PhD or Equivalent                 0
#   Compensation - Annual Base Salary/Pay Compensation - Annual Target Bonus ($)
# 1    123                                123
# 2 160000                                16000
# 3  55000                                4400
# 4  28000                                Not Applicable/None
# 5  72800                                5824
# 6 120000                                0.08
#   Compensation - Annual Equity [OPTIONAL]  Sign on Bonus Value
# 1 Not Applicable/None            123
# 2 30000                        10000
# 3 Not Applicable/None             NA
# 4 Not Applicable/None             NA
# 5 Not Applicable/None             NA
# 6 Not Applicable/None           7000
#   [OPTIONAL] Sign on - Relocation Assistance Total Value
# 1 12e
# 2 NULL
# 3 NULL
# 4 NULL
# 5 NULL
# 6 15000

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# 📈 Make a chart that shows the relationship between `Years of Experience` and `Compensation - Annual Base Salary/Pay`.
#
# ❗️ Remember that you need to use backticks to access columns whose names have spaces:
#
# ```
# `Years of Experience`
# ```

# %%
p=ggplot(salary, aes(x=`Years of Experience`, y=`Compensation - Annual Base Salary/Pay`)) + geom_point(color=)

         p
# Out:
# Error in layer(data = data, mapping = mapping, stat = stat, geom = GeomPoint, : argument is missing, with no default
# Traceback:
#
# 1. geom_point(color = )
# 2. layer(data = data, mapping = mapping, stat = stat, geom = GeomPoint,
#  .     position = position, show.legend = show.legend, inherit.aes = inherit.aes,
#  .     params = list(na.rm = na.rm, ...))

# %% [markdown]
# 📊 Count the number of respondents that belong to each `Highest achieved Formal Education` category. You can do this visually with `geom_bar` or in table form with `dplyr`...

# %%
salary |>
    group_by(`Highest achieved Formal Education`) |>
    summarize(n_respondents=n())

# %% [markdown]
# 📊 Make a histogram of `Compensation - Annual Base Salary/Pay` for respondents in the `Bachelors or Equivalent` group from the `Highest achieved Formal Education` column.,

# %%
# or you can do:
salary |> count(`Highest achieved Formal Education`)
# Out:
#   Highest achieved Formal Education n
# 1 Associate’s Degree or Equivalent   11
# 2 Bachelors or Equivalent           193
# 3 High School or Equivalent           5
# 4 M.D./PharmD/D.D.S. or Equivalent    3
# 5 Masters or Equivalent              73
# 6 PhD or Equivalent                 167

# %%
#third way is to plot it

ggplot(salary, aes(y=`Highest achieved Formal Education`)) + geom_bar()
p
# Out:
# Error in eval(expr, envir, enclos): object 'p' not found
# Traceback:
# plot without title

# %%
salary_data_bs = salary |> 
    filter(`Highest achieved Formal Education` == 'Bachelors or Equivalent')

p = ggplot(salary_data_bs, aes(x = `Compensation - Annual Base Salary/Pay`)) +
    geom_histogram() +
    scale_x_continuous(labels = scales::dollar_format())

p
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
