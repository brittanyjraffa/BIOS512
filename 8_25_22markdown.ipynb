# %%
print('test')
# Out:
# [1] "test"

# %% [markdown]
# # Big heading

# %%
### Small heading

# %% [markdown]
# - now I have dialogue `like this`

# %% [markdown]
# and can hover over text and edit it

# %% [markdown]
# # Another heading
